# %%
import main as tools

final_dataFrame = tools.all_data_concat()
print(final_dataFrame.info())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 3
#       1 import main as tools
# ----> 3 final_dataFrame = tools.all_data_concat()
#       4 print(final_dataFrame.info())
#
# AttributeError: module 'main' has no attribute 'all_data_concat'

# %%
# groupby
import numpy as np
import pandas as pd

df = pd.DataFrame({'key1':['a', 'a', 'b', 'b', 'a'],
                  'key2':['one', 'two', 'one', 'two', 'one'],
                  'data1': np.random.randn(5),
                  'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -1.261668 -0.044884
# 1    a  two  1.048315 -1.192218
# 2    b  one -1.596500 -0.701489
# 3    b  two -2.423432 -0.402067
# 4    a  one  0.494437 -0.703308

# %%
df.groupby('key1')["data1"].mean()
df.groupby('key1')[["data1","data2"]].mean()
df1 = df.groupby(['key1','key2']).mean()
df1
# Out:
#               data1     data2
# key1 key2
# a    one  -0.383616 -0.374096
#      two   1.048315 -1.192218
# b    one  -1.596500 -0.701489
#      two  -2.423432 -0.402067

# %%
df2 = df1.stack() # 變成長的資料
df2.index.names = ['key1','key2','data']
df2
# Out:
# key1  key2  data
# a     one   data1   -0.383616
#             data2   -0.374096
#       two   data1    1.048315
#             data2   -1.192218
# b     one   data1   -1.596500
#             data2   -0.701489
#       two   data1   -2.423432
#             data2   -0.402067
# dtype: float64

# %%
df3 = df2.unstack(level=["data",'key1']) # 變回寬的資料
df3
# Out:
# data     data1     data2     data1     data2
# key1         a         a         b         b
# key2
# one  -0.383616 -0.374096 -1.596500 -0.701489
# two   1.048315 -1.192218 -2.423432 -0.402067

# %%
df3['data1']
# Out:
# key1         a         b
# key2
# one  -0.383616 -1.596500
# two   1.048315 -2.423432

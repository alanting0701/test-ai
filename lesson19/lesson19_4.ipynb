# %%
import main as tools
final_dataFrame = tools.all_data_concat()
print(final_dataFrame.info())
final_dataFrame.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 import main as tools
# ----> 2 final_dataFrame = tools.all_data_concat()
#       3 print(final_dataFrame.info())
#       4 final_dataFrame.head()
#
# AttributeError: module 'main' has no attribute 'all_data_concat'

# %%
import pandas as pd

final_dataFrame['乘車日期'] = pd.to_datetime(final_dataFrame['乘車日期'], format='%Y%m%d')
final_dataFrame.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pandas as pd
# ----> 3 final_dataFrame['乘車日期'] = pd.to_datetime(final_dataFrame['乘車日期'], format='%Y%m%d')
#       4 final_dataFrame.head()
#
# NameError: name 'final_dataFrame' is not defined

# %%
final_dataFrame.groupby("車站名稱")[["進站人數","出站人數"]].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 final_dataFrame.groupby("車站名稱")[["進站人數","出站人數"]].sum()
#
# NameError: name 'final_dataFrame' is not defined

# %%
# 如何groupby多欄位,依據年份groupby
final_dataFrame['year'] = final_dataFrame['乘車日期'].dt.year
df1 = final_dataFrame.groupby(['year',"車站名稱"])[["進站人數","出站人數"]].sum()
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # 如何groupby多欄位,依據年份groupby
# ----> 2 final_dataFrame['year'] = final_dataFrame['乘車日期'].dt.year
#       3 df1 = final_dataFrame.groupby(['year',"車站名稱"])[["進站人數","出站人數"]].sum()
#       4 df1
#
# NameError: name 'final_dataFrame' is not defined

# %%
df2 = df1.unstack(level="year")
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df2 = df1.unstack(level="year")
#       2 df2
#
# NameError: name 'df1' is not defined

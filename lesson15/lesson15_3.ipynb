# %%
import numpy as np

students = np.random.randint(50, high=101, size=(50,5))
students.shape
# Out:
# (50, 5)

# %%
#ndarray的實體方法
students.sum(axis=1)  #每個學生的總分
students.mean(axis=1) #每個學生的平均分
# Out:
# array([75.4, 88.6, 78.8, 67.2, 84.2, 62.4, 71. , 74.4, 73.6, 76.8, 71.4,
#        70.8, 64. , 70.8, 84.8, 74.2, 74.4, 72.4, 65.2, 75.6, 83.4, 77.4,
#        78.6, 82.6, 67.2, 73.6, 70.6, 77.2, 80.2, 76.6, 74.8, 79.4, 73.4,
#        61.6, 78.4, 69.8, 63.2, 72.2, 78.4, 77.8, 78.8, 62.6, 75.4, 78.8,
#        68.4, 76. , 68.8, 73.8, 67.2, 61.6])

# %%
#numpy內建的函式

np.sum(students, axis=1)  #每個科目的總分
np.mean(students, axis=1) #每個科目的平均分
# Out:
# array([75.4, 88.6, 78.8, 67.2, 84.2, 62.4, 71. , 74.4, 73.6, 76.8, 71.4,
#        70.8, 64. , 70.8, 84.8, 74.2, 74.4, 72.4, 65.2, 75.6, 83.4, 77.4,
#        78.6, 82.6, 67.2, 73.6, 70.6, 77.2, 80.2, 76.6, 74.8, 79.4, 73.4,
#        61.6, 78.4, 69.8, 63.2, 72.2, 78.4, 77.8, 78.8, 62.6, 75.4, 78.8,
#        68.4, 76. , 68.8, 73.8, 67.2, 61.6])

# %%
#1家分店30天的營收

oneStore = np.random.randint(100, 10000, size=(30,))
oneStore
# Out:
# array([ 142, 9009,  558, 2805, 2425, 6761, 6933, 6742, 2514, 3764, 6307,
#        2695, 2444, 1513, 7808, 1730, 1751, 2223, 5970, 3538, 5023, 8750,
#        9513, 7573, 6298, 2512, 8699, 9893, 3040, 3460], dtype=int32)

# %%
#累計每天這家店的營收
import matplotlib.pyplot as plt

oneStoreCum = oneStore.cumsum()
oneStoreCum

figure = plt.figure(figsize=(10,5))
axes = figure.add_subplot(1,1,1)
axes.plot(range(1,31), oneStoreCum,'r-')
axes.set_title("one Store shop sumsum")
axes.set_xlabel("day")
axes.set_ylabel("money")
plt.show()

# %%
#5家店30天的營收

fiveStore = np.random.randint(100, 10000, size=(5,30))
fiveStore
# Out:
# array([[7117,  651, 6546, 1923, 1333, 5671,  337,  114,  662, 6338, 1010,
#         2375, 5016, 2405, 8397, 4788, 8946, 3919, 6790, 6979, 9648, 5218,
#         7990, 1246, 6915, 9615, 2006,  595, 5658, 7680],
#        [7658, 9011, 1273, 9061, 1478, 7489, 9476, 3390, 7046, 6364, 5213,
#          500, 1484, 7627, 2521, 3402, 3737,  742, 6268, 1920, 1202, 4713,
#         2932, 8686,  744, 8057,  847, 4857, 2380, 5502],
#        [9522, 1459, 5576, 6063, 6352, 7458, 7927, 8409, 3605, 5854, 6765,
#         3173, 9417, 1292, 5158,  425, 8354, 1231, 2477, 4927, 1650, 2962,
#         4322, 1057, 8521, 2087, 9308, 3759, 7251, 9641],
#        [5731, 7967, 4219, 2695, 4313, 1790, 5295, 2105, 5325,  300, 3588,
#         6039, 7601, 3431, 4293, 9762, 2184, 1011, 6943, 5294, 3746, 1976,
#          297, 3184, 4032, 4641, 2677,  783, 3369, 8897],
#        [9603, 1095,  751,  871, 3253,  206, 5844, 8654, 4603, 3398, 1811,
#         6581, 3031, 6781,  105, 3408, 5113, 1766, 4963, 7773, 2495, 9811,
#         7540, 8833, 9767, 4662, 7370, 3779, 5567, 4944]], dtype=int32)

# %%
#累計每天5家店的營收

fiveStoreCum = fiveStore.cumsum(axis=1)
fiveStoreCum
# Out:
# array([[  7117,   7768,  14314,  16237,  17570,  23241,  23578,  23692,
#          24354,  30692,  31702,  34077,  39093,  41498,  49895,  54683,
#          63629,  67548,  74338,  81317,  90965,  96183, 104173, 105419,
#         112334, 121949, 123955, 124550, 130208, 137888],
#        [  7658,  16669,  17942,  27003,  28481,  35970,  45446,  48836,
#          55882,  62246,  67459,  67959,  69443,  77070,  79591,  82993,
#          86730,  87472,  93740,  95660,  96862, 101575, 104507, 113193,
#         113937, 121994, 122841, 127698, 130078, 135580],
#        [  9522,  10981,  16557,  22620,  28972,  36430,  44357,  52766,
#          56371,  62225,  68990,  72163,  81580,  82872,  88030,  88455,
#          96809,  98040, 100517, 105444, 107094, 110056, 114378, 115435,
#         123956, 126043, 135351, 139110, 146361, 156002],
#        [  5731,  13698,  17917,  20612,  24925,  26715,  32010,  34115,
#          39440,  39740,  43328,  49367,  56968,  60399,  64692,  74454,
#          76638,  77649,  84592,  89886,  93632,  95608,  95905,  99089,
#         103121, 107762, 110439, 111222, 114591, 123488],
#        [  9603,  10698,  11449,  12320,  15573,  15779,  21623,  30277,
#          34880,  38278,  40089,  46670,  49701,  56482,  56587,  59995,
#          65108,  66874,  71837,  79610,  82105,  91916,  99456, 108289,
#         118056, 122718, 130088, 133867, 139434, 144378]])

# %%
#累計每天5家店的營收
import matplotlib.pyplot as plt


figure = plt.figure(figsize=(10,5))
axes = figure.add_subplot(1,1,1)
axes.plot(range(1,31), fiveStoreCum[0,:],'r-')
axes.plot(range(1,31), fiveStoreCum[1,:],'y-')
axes.plot(range(1,31), fiveStoreCum[2,:],'g-')
axes.plot(range(1,31), fiveStoreCum[3,:],'m-')
axes.plot(range(1,31), fiveStoreCum[4,:],'c-')
axes.set_title("five Store shop sumsum")
axes.set_xlabel("day")
axes.set_ylabel("money")
plt.show()

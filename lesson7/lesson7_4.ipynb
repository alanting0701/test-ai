# %%
# 開啟同一資料夾內的 names.txt
with open("names.txt", "r", encoding="utf-8") as file:
    # 讀取所有內容，並存在變數中
    content = file.read()

names = content.split('\n')
# for name in names:
#     print(name)

print(names[:5])
print(names[-5:])
# Out:
# ['陳怡伶', '馮芳如', '蒙淑惠', '張軒宸', '陳向愛']
# ['李淑芳', '謝南慧', '趙家豪', '龐皓芳', '張彥博']

# %%
content2 = 'apple,banana,orange'
con_list = content2.split(",")
con_list
# Out:
# ['apple', 'banana', 'orange']

# %%
open('names.txt')
# Out:
# <_io.TextIOWrapper name='names.txt' mode='r' encoding='UTF-8'>

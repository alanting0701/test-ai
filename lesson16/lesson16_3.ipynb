# %%
import pandas as pd
df = pd.read_csv('各鄉鎮市區人口密度.csv')
# 顯示欄位名稱
print(type(df.columns))

# 轉成 list 並顯示
cols = df.columns.tolist()
cols
# Out:
# <class 'pandas.core.indexes.base.Index'>
# ['statistic_yyy', 'site_id', 'people_total', 'area', 'population_density']

# %%
df = pd.read_csv('各鄉鎮市區人口密度.csv')
# 取出欄位名稱
cols = df.columns.tolist()
cols
# Out:
# ['statistic_yyy', 'site_id', 'people_total', 'area', 'population_density']

# %%
# 如何更改df的欄位名稱
# 如何更改df的欄位名稱
# 使用已存在的 cols 列表重新命名欄位
df.columns = df.loc[0].tolist()
# 刪除第一列，因為它已經成為新的欄位名稱
df1 = df.drop(index=0).reset_index(drop=True)
# 顯示前10列確認
df1.head(10)

# 顯示最後10列
df1.tail(10)
# 如何刪除index(370)以後的資料
#df2 = df1[df1.index <= 370]
#df1.drop(index=[370,371,372,372,373,374])
df2 = df1.reindex(index=range(0,370))
df2
# Out:
#      統計年     區域別   年底人口數     土地面積   人口密度
# 0    106  新北市板橋區  551480  23.1373  23835
# 1    106  新北市三重區  387484   16.317  23747
# 2    106  新北市中和區  413590   20.144  20532
# 3    106  新北市永和區  222585   5.7138  38956
# 4    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 365  106  連江縣北竿鄉    2360      9.9    238
# 366  106  連江縣莒光鄉    1624      4.7    346
# 367  106  連江縣東引鄉    1352      3.8    356
# 368  106    東沙群島      …      2.38     …
# 369  106    南沙群島      …    0.5045     …
#
# [370 rows x 5 columns]

# %%
# 查詢所有df2欄位的資料型態
df2.dtypes
# 如何將年底人口欄位轉成整數型態
# 先移除非數字字元（包含中文省略號等），再轉為數值，最後轉為 pandas 的 nullable integer dtype
df2['年底人口數'] = pd.to_numeric(
    df2['年底人口數'].astype(str).str.replace(r'[^\d]', '', regex=True),
    errors='coerce'
).astype('Int64')

# %%
#df2['年底人口數'].astype(int)
# df2['年底人口數']內容有`… `,無法直接轉成整數,如何置換為0
df2['年底人口數'] = df2['年底人口數'].replace('… ', '0').astype(int)
df2['人口密度'] = df2['人口密度'].replace('… ', '0').astype(int)
df2['土地面積'] = df2['土地面積'].astype(float)
df2.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 #df2['年底人口數'].astype(int)
#       2 # df2['年底人口數']內容有`… `,無法直接轉成整數,如何置換為0
# ----> 3 df2['年底人口數'] = df2['年底人口數'].replace('… ', '0').astype(int)
#       4 df2['人口密度'] = df2['人口密度'].replace('… ', '0').astype(int)
#       5 df2['土地面積'] = df2['土地面積'].astype(float)
#
# File c:\Users\alunt\OneDrive\文件\github\test-ai\.venv\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
# ...

# %%
#df2['土地面積']的內容是float型態,如何只顯示小數點後3位
df2['土地面積'] = df2['土地面積'].round(3)
df2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 #df2['土地面積']的內容是float型態,如何只顯示小數點後3位
# ----> 2 df2['土地面積'] = df2['土地面積'].round(3)
#       3 df2
#
# File c:\Users\alunt\OneDrive\文件\github\test-ai\.venv\Lib\site-packages\pandas\core\series.py:2821, in Series.round(self, decimals, *args, **kwargs)
#    2819 nv.validate_round(args, kwargs)
#    2820 if self.dtype == "object":
# -> 2821     raise TypeError("Expected numeric dtype, got object instead.")
#    2822 new_mgr = self._mgr.round(decimals=decimals, using_cow=using_copy_on_write())
#    2823 return self._constructor_from_mgr(new_mgr, axes=new_mgr.axes).__finalize__(
#    2824     self, method="round"
#    2825 )
#
# TypeError: Expected numeric dtype, got object instead.

# %%
import sys, subprocess
import importlib

# 如何將df2存成新的csv檔案
df2.to_csv('各鄉鎮市區人口密度_清理後.csv', index=False)
# 如何將df2存成新的excel檔案
df2.to_excel('各鄉鎮市區人口密度_清理後.xlsx', index=False)
# 確保 openpyxl 已安裝（若未安裝則透過 pip 安裝）
try:
    import openpyxl  # type: ignore
except ModuleNotFoundError:
    print("openpyxl not found. Installing...")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 7
#       5 df2.to_csv('各鄉鎮市區人口密度_清理後.csv', index=False)
#       6 # 如何將df2存成新的excel檔案
# ----> 7 df2.to_excel('各鄉鎮市區人口密度_清理後.xlsx', index=False)
#       8 # 確保 openpyxl 已安裝（若未安裝則透過 pip 安裝）
#       9 try:
#
# File c:\Users\alunt\OneDrive\文件\github\test-ai\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
import sys, subprocess
import importlib

# 如何將df2存成新的csv檔案
df2.to_csv('各鄉鎮市區人口密度_清理後.csv', index=False)
# 如何將df2存成新的excel檔案
df2.to_excel('各鄉鎮市區人口密度_清理後.xlsx', index=False)
# 確保 openpyxl 已安裝（若未安裝則透過 pip 安裝）
try:
    import openpyxl  # type: ignore
except ModuleNotFoundError:
    print("openpyxl not found. Installing...")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 7
#       5 df2.to_csv('各鄉鎮市區人口密度_清理後.csv', index=False)
#       6 # 如何將df2存成新的excel檔案
# ----> 7 df2.to_excel('各鄉鎮市區人口密度_清理後.xlsx', index=False)
#       8 # 確保 openpyxl 已安裝（若未安裝則透過 pip 安裝）
#       9 try:
#
# File c:\Users\alunt\OneDrive\文件\github\test-ai\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

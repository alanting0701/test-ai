# %%
class Person:
    def __init__(self,name:str,age:int):#自訂的初始化
        self.name = name
        self.age = 25

# %%
p1 = Person("AlanTing",30)
print(p1.name)
print(p1.age)
# Out:
# AlanTing
# 25

# %%
p2 = Person(age=35,name="mimi")
print(p2.name)
print(p2.age)
# Out:
# mimi
# 25

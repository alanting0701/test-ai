# %%
import pandas as pd

sales = pd.Series([300, 600, 450, 800, 200, 700], 
                  index=['A', 'B', 'C', 'D', 'E', 'F'])

high_sales = sales > 500
print(high_sales)
sales_above_500 = sales[high_sales]
print(sales_above_500)
# Out:
# A    False
# B     True
# C    False
# D     True
# E    False
# F     True
# dtype: bool
# B    600
# D    800
# F    700
# dtype: int64
